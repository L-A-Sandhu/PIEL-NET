# %% [markdown]
# # PIEL-NET Pipeline (Notebook)
# This notebook mirrors `main.py` and runs the end-to-end PIEL-NET pipeline for city–region temperature forecasting.
# - Physics prior (advection–diffusion) → LMS baseline → hybrid alignment
# - ConvLSTM baseline (V4) and RAFL-specialized expert (V5)
# - edRVFL-SC ensemble fusion → save final metrics and predictions
#
# > **Note:** Ensure your environment can import `ed_rvfl_sc`. If you package it as a module, place it on `PYTHONPATH` or next to this notebook.

# %% [markdown]
# ## 0) (Optional) Install dependencies
# If you already set up a virtualenv with `requirements.txt`, skip this cell.

# %%
# !pip install -r requirements.txt
#
# Out:
# Collecting ed_rvfl_sc==0.1.1 (from -r requirements.txt (line 1))
#   Using cached ed_rvfl_sc-0.1.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: matplotlib==3.8.4 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (3.8.4)
# Requirement already satisfied: numpy==1.26.4 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: onnx==1.17.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: onnxruntime==1.20.1 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (1.20.1)
# Requirement already satisfied: pandas==2.0.3 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (2.0.3)
# Requirement already satisfied: scipy==1.15.3 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (1.15.3)
# Requirement already satisfied: scikit-fuzzy==0.5.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (0.5.0)
# Requirement already satisfied: scikit-learn==1.7.1 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (1.7.1)
# Requirement already satisfied: tensorflow==2.19.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (2.19.0)
# Requirement already satisfied: tf2onnx==1.16.1 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (1.16.1)
# Requirement already satisfied: keras<4.0,>=3.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from ed_rvfl_sc==0.1.1->-r requirements.txt (line 1)) (3.10.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from scikit-learn==1.7.1->-r requirements.txt (line 9)) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from scikit-learn==1.7.1->-r requirements.txt (line 9)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 2)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 2)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 2)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 2)) (25.0)
# Requirement already satisfied: pillow>=8 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 2)) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 2)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: protobuf>=3.20.2 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from onnx==1.17.0->-r requirements.txt (line 4)) (4.21.12)
# Requirement already satisfied: coloredlogs in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from onnxruntime==1.20.1->-r requirements.txt (line 5)) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from onnxruntime==1.20.1->-r requirements.txt (line 5)) (25.2.10)
# Requirement already satisfied: sympy in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from onnxruntime==1.20.1->-r requirements.txt (line 5)) (1.13.3)
# Requirement already satisfied: pytz>=2020.1 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from pandas==2.0.3->-r requirements.txt (line 6)) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from pandas==2.0.3->-r requirements.txt (line 6)) (2025.1)
# Requirement already satisfied: absl-py>=1.0.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from tensorflow==2.19.0->-r requirements.txt (line 10)) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from tensorflow==2.19.0->-r requirements.txt (line 10)) (1.6.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from tensorflow==2.19.0->-r requirements.txt (line 10)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from tensorflow==2.19.0->-r requirements.txt (line 10)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from tensorflow==2.19.0->-r requirements.txt (line 10)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from tensorflow==2.19.0->-r requirements.txt (line 10)) (3.4.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from tensorflow==2.19.0->-r requirements.txt (line 10)) (2.32.4)
# Requirement already satisfied: setuptools in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from tensorflow==2.19.0->-r requirements.txt (line 10)) (79.0.1)
# Requirement already satisfied: six>=1.12.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from tensorflow==2.19.0->-r requirements.txt (line 10)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from tensorflow==2.19.0->-r requirements.txt (line 10)) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from tensorflow==2.19.0->-r requirements.txt (line 10)) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from tensorflow==2.19.0->-r requirements.txt (line 10)) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from tensorflow==2.19.0->-r requirements.txt (line 10)) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from tensorflow==2.19.0->-r requirements.txt (line 10)) (2.19.0)
# Requirement already satisfied: h5py>=3.11.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from tensorflow==2.19.0->-r requirements.txt (line 10)) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from tensorflow==2.19.0->-r requirements.txt (line 10)) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from tensorflow==2.19.0->-r requirements.txt (line 10)) (0.37.1)
# Collecting protobuf>=3.20.2 (from onnx==1.17.0->-r requirements.txt (line 4))
#   Using cached protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (679 bytes)
# Requirement already satisfied: rich in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from keras<4.0,>=3.0->ed_rvfl_sc==0.1.1->-r requirements.txt (line 1)) (14.0.0)
# Requirement already satisfied: namex in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from keras<4.0,>=3.0->ed_rvfl_sc==0.1.1->-r requirements.txt (line 1)) (0.1.0)
# Requirement already satisfied: optree in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from keras<4.0,>=3.0->ed_rvfl_sc==0.1.1->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.19.0->-r requirements.txt (line 10)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.19.0->-r requirements.txt (line 10)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.19.0->-r requirements.txt (line 10)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.19.0->-r requirements.txt (line 10)) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow==2.19.0->-r requirements.txt (line 10)) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow==2.19.0->-r requirements.txt (line 10)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow==2.19.0->-r requirements.txt (line 10)) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow==2.19.0->-r requirements.txt (line 10)) (0.45.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow==2.19.0->-r requirements.txt (line 10)) (3.0.2)
# Requirement already satisfied: humanfriendly>=9.1 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from coloredlogs->onnxruntime==1.20.1->-r requirements.txt (line 5)) (10.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from rich->keras<4.0,>=3.0->ed_rvfl_sc==0.1.1->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from rich->keras<4.0,>=3.0->ed_rvfl_sc==0.1.1->-r requirements.txt (line 1)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras<4.0,>=3.0->ed_rvfl_sc==0.1.1->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages (from sympy->onnxruntime==1.20.1->-r requirements.txt (line 5)) (1.3.0)
# Using cached ed_rvfl_sc-0.1.1-py3-none-any.whl (5.4 kB)
# Using cached protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
# Installing collected packages: protobuf, ed_rvfl_sc
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.21.12
#     Uninstalling protobuf-4.21.12:
#       Successfully uninstalled protobuf-4.21.12
#   Attempting uninstall: ed_rvfl_sc
#     Found existing installation: ed-rvfl-sc 0.1.0
#     Uninstalling ed-rvfl-sc-0.1.0:
#       Successfully uninstalled ed-rvfl-sc-0.1.038;5;237m╺━━━━━━━━━━━━━━━━━━━ 1/2 [ed_rvfl_sc]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [ed_rvfl_sc] 1/2 [ed_rvfl_sc]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-tools 1.70.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# tensorflow-metadata 1.17.2 requires protobuf<4.22,>=4.21.6; python_version < "3.11", but you have protobuf 3.20.3 which is incompatible.
# tf-swin-unet 0.1.0 requires matplotlib<4.0.0,>=3.10.1, but you have matplotlib 3.8.4 which is incompatible.
# Successfully installed ed_rvfl_sc-0.1.1 protobuf-3.20.3
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## 1) Imports and path setup

# %%
import os, json, sys, numpy as np

# Make sure local src/ is importable if you keep modules there
sys.path.insert(0, './src')

from data_loader import load_data
from advection import get_optimized_physics_predictions
from matric import calculate_metrics
from data_transform import transform_X
from error_compute import calculate_combined_errors
from extract_target_column import extract_target_column
from fuzzy_mem import compute_fuzzy_memberships
from PIEL_NET import HybridModel

# Optional expert: ensure this is installed or available on path
from ed_rvfl_sc import edRVFL_SC
# Out:
# 2025-10-03 22:52:55.591713: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759503175.613544 4116207 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759503175.620407 4116207 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1759503175.637229 4116207 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759503175.637245 4116207 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759503175.637247 4116207 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759503175.637249 4116207 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-03 22:52:55.643066: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## 2) Parameters (replace argparse)
# Adjust paths and hyperparameters below. The defaults match `main.py`.

# %%
from types import SimpleNamespace

args = SimpleNamespace(
    # Data + IO
    data_dir = "./Data",
    results_root = "Results/Ablation",
    output_name = "C_T2M",
    # Sequence config
    T = 48,  # input window
    S = 12,  # stride
    H = 12,  # horizon
    # Training
    epochs = 1000,
    batch_size = 32,
    patience = 10,
    # Loss config
    loss_type_v4 = "MAE",         # ["MAE", "MSE", "focal"]
    loss_type_v5 = "focal",       # ["MAE", "MSE", "focal"]
    alpha_w = 0.2,
    beta_w = 2.0,
    gamma_w = 5.0,
    eta = 0.1,
    focal_gamma = 5.0,
    # edRVFL-SC
    rvfl_units = 256,
    rvfl_lambda = 1e-3,
    rvfl_Lmax = 7,
    rvfl_deep_boost = 0.9,
    # Misc
    seed = 42
)
np.random.seed(args.seed)

# %% [markdown]
# ## 3) Utilities

# %%
def ensure_dir(path: str):
    os.makedirs(path, exist_ok=True)
    return path

# %% [markdown]
# ## 4) Run the pipeline
# This cell processes all `.csv` files in `args.data_dir` and saves only the **final** ensemble results under `Results/<dataset>/PIELNET/`.

# %%
# Create results root
ensure_dir(args.results_root)

for csv_file in sorted(os.listdir(args.data_dir)):
    if not csv_file.endswith(".csv"):
        continue

    csv_path = os.path.join(args.data_dir, csv_file)
    dataset = os.path.splitext(csv_file)[0]
    run_dir = ensure_dir(os.path.join(args.results_root, dataset))
    final_dir = ensure_dir(os.path.join(run_dir, "PIELNET"))  # unified folder name

    print(f"\n=== Processing dataset: {dataset} ===")

    # ---- Load & window ----
    X_train, Y_train, X_val, Y_val, X_test, Y_test, norm_stats, col_map = load_data(
        csv_path=csv_path, T=args.T, S=args.S, H=args.H, output_dir=None
    )

    # ---- Physics predictions ----
    Y_train_phy, Y_val_phy, Y_test_phy, _ = get_optimized_physics_predictions(
        X_train, Y_train, X_val, X_test, norm_stats, col_map, args.H
    )

    # Align physics predictions via linear map
    A = np.linalg.pinv(Y_train_phy) @ Y_train
    Y_train_phy = Y_train_phy @ A
    Y_val_phy   = Y_val_phy   @ A
    Y_test_phy  = Y_test_phy  @ A

    # ---- LMS baseline over raw features ----
    Xtr = X_train.reshape(X_train.shape[0], -1)
    Xva = X_val.reshape(X_val.shape[0], -1)
    Xte = X_test.reshape(X_test.shape[0], -1)
    W_lms, *_ = np.linalg.lstsq(Xtr, Y_train, rcond=None)
    Y_est_train = Xtr @ W_lms
    Y_est_val   = Xva @ W_lms
    Y_est_test  = Xte @ W_lms

    # ---- Physics + LMS hybrid projection ----
    Y_train_H = np.hstack([Y_est_train, Y_train_phy])
    Y_val_H   = np.hstack([Y_est_val,   Y_val_phy])
    Y_test_H  = np.hstack([Y_est_test,  Y_test_phy])

    A2 = np.linalg.pinv(Y_train_H) @ Y_train
    Y_train_H = Y_train_H @ A2
    Y_val_H   = Y_val_H   @ A2
    Y_test_H  = Y_test_H  @ A2

    # ---- Error signals & memberships ----
    Err_train = calculate_combined_errors(Y_train_H, Y_train)
    Err_val   = calculate_combined_errors(Y_val_H,   Y_val)

    # Not used later but available if needed (kept for parity with main.py)
    _ = extract_target_column(X_train, col_map, target_col=args.output_name)

    train_memberships, val_memberships = compute_fuzzy_memberships(
        Err_train, Err_val, mf_type="triangle"
    )

    # ---- Data transform for ConvLSTM model ----
    X_train_P = np.expand_dims(transform_X(X_train, col_map)[0], axis=-1)
    X_val_P   = np.expand_dims(transform_X(X_val,   col_map)[0], axis=-1)
    X_test_P  = np.expand_dims(transform_X(X_test,  col_map)[0], axis=-1)

    # Pack labels with error + memberships
    YY_train = np.column_stack((Y_train, Err_train, train_memberships))
    YY_val   = np.column_stack((Y_val,   Err_val,   val_memberships))

    # ---- Data model V4 ----
    data_model = HybridModel(
        input_shape=X_train_P.shape[1:],
        pi_dim=Y_train.shape[1],
        checkpoint_path=os.path.join(run_dir, "_tmp_ignore_v4"),
        loss_type=args.loss_type_v4,
        alpha=args.alpha_w, beta=args.beta_w, gamma=args.gamma_w,
        eta=args.eta, focal_gamma=args.focal_gamma
    )
    data_model.fit(
        X_train_P, YY_train,
        validation_data=(X_val_P, YY_val),
        epochs=args.epochs, batch_size=args.batch_size, patience=args.patience
    )
    Y_train_D = data_model.predict(X_train_P)
    Y_val_D   = data_model.predict(X_val_P)
    Y_test_D  = data_model.predict(X_test_P)

    # ---- Data model V5 (RAFL) ----
    data_model_F = HybridModel(
        input_shape=X_train_P.shape[1:],
        pi_dim=Y_train.shape[1],
        checkpoint_path=os.path.join(run_dir, "_tmp_ignore_v5"),
        loss_type=args.loss_type_v5,
        alpha=args.alpha_w, beta=args.beta_w, gamma=args.gamma_w,
        eta=args.eta, focal_gamma=args.focal_gamma
    )
    data_model_F.fit(
        X_train_P, YY_train,
        validation_data=(X_val_P, YY_val),
        epochs=args.epochs, batch_size=args.batch_size, patience=args.patience
    )
    Y_train_FD = data_model_F.predict(X_train_P)
    Y_val_FD   = data_model_F.predict(X_val_P)
    Y_test_FD  = data_model_F.predict(X_test_P)

    # ---- Final ensemble (edRVFL-SC) ----
    Z_train = np.hstack([Y_train_D, Y_train_FD, Y_train_H])
    Z_val   = np.hstack([Y_val_D,   Y_val_FD,   Y_val_H])
    Z_test  = np.hstack([Y_test_D,  Y_test_FD,  Y_test_H])

    MOE = edRVFL_SC(
        num_units=args.rvfl_units,
        activation="relu",
        lambda_=args.rvfl_lambda,
        Lmax=args.rvfl_Lmax,
        deep_boosting=args.rvfl_deep_boost
    )
    MOE.train(Z_train, Y_train)
    Y_test_final = MOE.predict(Z_test)

    # ---- Persist only final metrics under PIELNET ----
    metrics_all = {}
    metrics_all["PIELNET"] = calculate_metrics(
        Y_test, Y_test_final, args.output_name, norm_stats, final_dir
    )

    # Also save a compact metrics.json at dataset root for quick scan
    with open(os.path.join(run_dir, "metrics.json"), "w") as f:
        json.dump(metrics_all, f, indent=4)

    print(f"✓ Completed {dataset} → {final_dir}")
# Out:
# === Processing dataset: Calgary ===
#
# Training Statistics:
# X shape: (5110, 48, 49)
# X min: -4.9660, X max: 6.5691, X mean: 0.0006
# Y shape: (5110, 12)
# Y min: -3.2547, Y max: 2.7794, Y mean: 0.0008
#
# Validation Statistics:
# X shape: (1091, 48, 49)
# X min: -5.2414, X max: 5.1212, X mean: 0.0242
# Y shape: (1091, 12)
# Y min: -3.3688, Y max: 2.4174, Y mean: -0.0218
#
# Test Statistics:
# X shape: (1092, 48, 49)
# X min: -4.2970, X max: 5.0762, X mean: 0.1159
# Y shape: (1092, 12)
# Y min: -3.8539, Y max: 2.6135, Y mean: 0.1349
#
# Column Mapping:
#  0: YEAR
#  1: MO
#  2: DY
#  3: HR
#  4: C_WS50M
#  5: C_WD50M
#  6: C_PS
#  7: C_QV2M
#  8: C_T2M
#  9: N_WS50M
# 10: N_WD50M
# 11: N_PS
# 12: N_QV2M
# 13: N_T2M
# 14: NE_WS50M
# 15: NE_WD50M
# 16: NE_PS
# 17: NE_QV2M
# 18: NE_T2M
# 19: E_WS50M
# 20: E_WD50M
# 21: E_PS
# 22: E_QV2M
# 23: E_T2M
# 24: SE_WS50M
# 25: SE_WD50M
# 26: SE_PS
# 27: SE_QV2M
# 28: SE_T2M
# 29: S_WS50M
# 30: S_WD50M
# 31: S_PS
# 32: S_QV2M
# 33: S_T2M
# 34: SW_WS50M
# 35: SW_WD50M
# 36: SW_PS
# 37: SW_QV2M
# 38: SW_T2M
# 39: W_WS50M
# 40: W_WD50M
# 41: W_PS
# 42: W_QV2M
# 43: W_T2M
# 44: NW_WS50M
# 45: NW_WD50M
# 46: NW_PS
# 47: NW_QV2M
# 48: NW_T2M
# differential_evolution step 1: f(x)= 0.48047732794136855
# differential_evolution step 2: f(x)= 0.48047732794136855
# differential_evolution step 3: f(x)= 0.48047732794136855
# differential_evolution step 4: f(x)= 0.48047732794136855
# Polishing solution with 'L-BFGS-B'
# Optimization succeeded | Loss: 0.4805
# α: 4.94e-03, β: 0.177
# I0000 00:00:1759503203.247305 4116207 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8092 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:03:00.0, compute capability: 8.6
# Epoch 1/1000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759503211.961492 4116487 service.cc:152] XLA service 0x597e49dc7570 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759503211.961518 4116487 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3080 Ti, Compute Capability 8.6
# 2025-10-03 22:53:32.253378: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1759503213.589485 4116487 cuda_dnn.cc:529] Loaded cuDNN version 90701
#   1/160 ━━━━━━━━━━━━━━━━━━━━ 41:23 16s/step - custom_mae: 0.5978 - loss: 0.5978
# I0000 00:00:1759503220.251385 4116487 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 44s 180ms/step - custom_mae: 0.4903 - loss: 0.4903 - val_custom_mae: 0.2898 - val_loss: 0.2898
# Epoch 2/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 108ms/step - custom_mae: 0.1591 - loss: 0.1591 - val_custom_mae: 0.2923 - val_loss: 0.2923
# Epoch 3/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 110ms/step - custom_mae: 0.1284 - loss: 0.1284 - val_custom_mae: 0.2881 - val_loss: 0.2881
# Epoch 4/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 107ms/step - custom_mae: 0.1192 - loss: 0.1192 - val_custom_mae: 0.2734 - val_loss: 0.2734
# Epoch 5/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 105ms/step - custom_mae: 0.1115 - loss: 0.1115 - val_custom_mae: 0.2843 - val_loss: 0.2843
# Epoch 6/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 109ms/step - custom_mae: 0.1105 - loss: 0.1105 - val_custom_mae: 0.2751 - val_loss: 0.2751
# Epoch 7/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 107ms/step - custom_mae: 0.1065 - loss: 0.1065 - val_custom_mae: 0.2887 - val_loss: 0.2887
# Epoch 8/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 105ms/step - custom_mae: 0.1011 - loss: 0.1011 - val_custom_mae: 0.2921 - val_loss: 0.2921
# Epoch 9/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 108ms/step - custom_mae: 0.1020 - loss: 0.1020 - val_custom_mae: 0.2792 - val_loss: 0.2792
# Epoch 10/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 109ms/step - custom_mae: 0.0966 - loss: 0.0966 - val_custom_mae: 0.3028 - val_loss: 0.3028
# Epoch 11/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 107ms/step - custom_mae: 0.0942 - loss: 0.0942 - val_custom_mae: 0.2950 - val_loss: 0.2950
# Epoch 12/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 104ms/step - custom_mae: 0.0971 - loss: 0.0971 - val_custom_mae: 0.2722 - val_loss: 0.2722
# Epoch 13/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 107ms/step - custom_mae: 0.0896 - loss: 0.0896 - val_custom_mae: 0.2860 - val_loss: 0.2860
# Epoch 14/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - custom_mae: 0.0895 - loss: 0.0895 - val_custom_mae: 0.2903 - val_loss: 0.2903
# Epoch 15/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 110ms/step - custom_mae: 0.0874 - loss: 0.0874 - val_custom_mae: 0.2848 - val_loss: 0.2848
# Epoch 16/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 109ms/step - custom_mae: 0.0854 - loss: 0.0854 - val_custom_mae: 0.2960 - val_loss: 0.2960
# Epoch 17/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 110ms/step - custom_mae: 0.0805 - loss: 0.0805 - val_custom_mae: 0.2909 - val_loss: 0.2909
# Epoch 18/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 107ms/step - custom_mae: 0.0785 - loss: 0.0785 - val_custom_mae: 0.2976 - val_loss: 0.2976
# Epoch 19/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 108ms/step - custom_mae: 0.0796 - loss: 0.0796 - val_custom_mae: 0.2919 - val_loss: 0.2919
# Epoch 20/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 108ms/step - custom_mae: 0.0766 - loss: 0.0766 - val_custom_mae: 0.2899 - val_loss: 0.2899
# Epoch 21/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 19s 115ms/step - custom_mae: 0.0726 - loss: 0.0726 - val_custom_mae: 0.2815 - val_loss: 0.2815
# Epoch 22/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 114ms/step - custom_mae: 0.0726 - loss: 0.0726 - val_custom_mae: 0.3002 - val_loss: 0.3002
# /home/lasandhu/yes/envs/tflow/lib/python3.10/site-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: main_input
# Received: inputs=['Tensor(shape=(None, 48, 5, 10, 1))']
#   warnings.warn(msg)
# I0000 00:00:1759503614.976124 4116207 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1759503614.976281 4116207 single_machine.cc:374] Starting new session
# I0000 00:00:1759503614.977179 4116207 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8092 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:03:00.0, compute capability: 8.6
# I0000 00:00:1759503615.312005 4116207 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8092 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:03:00.0, compute capability: 8.6
# I0000 00:00:1759503615.355056 4116207 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1759503615.355318 4116207 single_machine.cc:374] Starting new session
# I0000 00:00:1759503615.356639 4116207 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8092 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:03:00.0, compute capability: 8.6
# I0000 00:00:1759503615.836866 4116207 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8092 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:03:00.0, compute capability: 8.6
# I0000 00:00:1759503615.838208 4116207 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# I0000 00:00:1759503615.842996 4116207 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8092 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:03:00.0, compute capability: 8.6
# I0000 00:00:1759503615.848221 4116207 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8092 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:03:00.0, compute capability: 8.6
# I0000 00:00:1759503615.853606 4116207 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8092 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:03:00.0, compute capability: 8.6
# Epoch 1/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 39s 165ms/step - custom_mae: 0.5681 - loss: 0.1340 - val_custom_mae: 0.3772 - val_loss: 0.0042
# Epoch 2/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - custom_mae: 0.3344 - loss: 0.0260 - val_custom_mae: 0.3596 - val_loss: 0.0021
# Epoch 3/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - custom_mae: 0.2811 - loss: 0.0017 - val_custom_mae: 0.4732 - val_loss: 0.0184
# Epoch 4/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 114ms/step - custom_mae: 0.3384 - loss: 0.0111 - val_custom_mae: 0.3192 - val_loss: 7.4943e-04
# Epoch 5/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - custom_mae: 0.2541 - loss: 0.0024 - val_custom_mae: 0.4031 - val_loss: 0.0023
# Epoch 6/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 113ms/step - custom_mae: 0.2798 - loss: 0.0041 - val_custom_mae: 0.3209 - val_loss: 6.9027e-04
# Epoch 7/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 114ms/step - custom_mae: 0.2444 - loss: 0.0024 - val_custom_mae: 0.3034 - val_loss: 5.4312e-04
# Epoch 8/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 109ms/step - custom_mae: 0.2132 - loss: 1.9793e-04 - val_custom_mae: 0.2898 - val_loss: 3.0744e-04
# Epoch 9/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 110ms/step - custom_mae: 0.2068 - loss: 1.1395e-05 - val_custom_mae: 0.2873 - val_loss: 2.8200e-04
# Epoch 10/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 110ms/step - custom_mae: 0.2006 - loss: 7.8558e-06 - val_custom_mae: 0.2883 - val_loss: 2.8443e-04
# Epoch 11/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 108ms/step - custom_mae: 0.1954 - loss: 6.6645e-06 - val_custom_mae: 0.2878 - val_loss: 2.7551e-04
# Epoch 12/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 110ms/step - custom_mae: 0.1947 - loss: 5.0943e-06 - val_custom_mae: 0.2897 - val_loss: 2.8728e-04
# Epoch 13/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 114ms/step - custom_mae: 0.1923 - loss: 4.9979e-06 - val_custom_mae: 0.2879 - val_loss: 2.5759e-04
# Epoch 14/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 111ms/step - custom_mae: 0.1889 - loss: 3.8228e-06 - val_custom_mae: 0.2889 - val_loss: 2.6540e-04
# Epoch 15/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 114ms/step - custom_mae: 0.1870 - loss: 4.4771e-06 - val_custom_mae: 0.2885 - val_loss: 2.5989e-04
# Epoch 16/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 19s 118ms/step - custom_mae: 0.1866 - loss: 3.2021e-06 - val_custom_mae: 0.2893 - val_loss: 2.6773e-04
# Epoch 17/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 19s 116ms/step - custom_mae: 0.1862 - loss: 3.7050e-06 - val_custom_mae: 0.2889 - val_loss: 2.5325e-04
# Epoch 18/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 114ms/step - custom_mae: 0.1849 - loss: 3.0302e-06 - val_custom_mae: 0.2888 - val_loss: 2.4844e-04
# Epoch 19/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 114ms/step - custom_mae: 0.1834 - loss: 3.6670e-06 - val_custom_mae: 0.2882 - val_loss: 2.3708e-04
# Epoch 20/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 113ms/step - custom_mae: 0.1822 - loss: 2.8262e-06 - val_custom_mae: 0.2890 - val_loss: 2.4893e-04
# Epoch 21/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 19s 116ms/step - custom_mae: 0.1803 - loss: 2.6175e-06 - val_custom_mae: 0.2881 - val_loss: 2.3247e-04
# Epoch 22/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 114ms/step - custom_mae: 0.1789 - loss: 2.4499e-06 - val_custom_mae: 0.2892 - val_loss: 2.4389e-04
# Epoch 23/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 108ms/step - custom_mae: 0.1796 - loss: 2.2280e-06 - val_custom_mae: 0.2894 - val_loss: 2.4040e-04
# Epoch 24/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 115ms/step - custom_mae: 0.1789 - loss: 1.9762e-06 - val_custom_mae: 0.2900 - val_loss: 2.5548e-04
# Epoch 25/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 113ms/step - custom_mae: 0.1756 - loss: 1.7421e-06 - val_custom_mae: 0.2883 - val_loss: 2.2255e-04
# Epoch 26/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - custom_mae: 0.1789 - loss: 2.1567e-06 - val_custom_mae: 0.2891 - val_loss: 2.3078e-04
# Epoch 27/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 113ms/step - custom_mae: 0.1746 - loss: 1.5491e-06 - val_custom_mae: 0.2887 - val_loss: 2.2200e-04
# Epoch 28/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - custom_mae: 0.1762 - loss: 1.4900e-06 - val_custom_mae: 0.2886 - val_loss: 2.2046e-04
# Epoch 29/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 108ms/step - custom_mae: 0.1733 - loss: 1.2338e-06 - val_custom_mae: 0.2901 - val_loss: 2.2374e-04
# Epoch 30/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 107ms/step - custom_mae: 0.1741 - loss: 1.3232e-06 - val_custom_mae: 0.2908 - val_loss: 2.4254e-04
# Epoch 31/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 107ms/step - custom_mae: 0.1752 - loss: 1.6240e-06 - val_custom_mae: 0.2886 - val_loss: 2.0347e-04
# Epoch 32/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 109ms/step - custom_mae: 0.1735 - loss: 1.4988e-06 - val_custom_mae: 0.2908 - val_loss: 2.3213e-04
# Epoch 33/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 108ms/step - custom_mae: 0.1707 - loss: 1.1646e-06 - val_custom_mae: 0.2900 - val_loss: 2.1372e-04
# Epoch 34/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 113ms/step - custom_mae: 0.1722 - loss: 1.0202e-06 - val_custom_mae: 0.2889 - val_loss: 2.0491e-04
# Epoch 35/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 115ms/step - custom_mae: 0.1707 - loss: 1.0659e-06 - val_custom_mae: 0.2908 - val_loss: 2.2089e-04
# Epoch 36/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - custom_mae: 0.1725 - loss: 1.1670e-06 - val_custom_mae: 0.2915 - val_loss: 2.3517e-04
# Epoch 37/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 114ms/step - custom_mae: 0.1704 - loss: 1.0208e-06 - val_custom_mae: 0.2919 - val_loss: 2.2931e-04
# Epoch 38/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 113ms/step - custom_mae: 0.1706 - loss: 9.5456e-07 - val_custom_mae: 0.2926 - val_loss: 2.3177e-04
# Epoch 39/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 106ms/step - custom_mae: 0.1689 - loss: 8.7067e-07 - val_custom_mae: 0.2908 - val_loss: 2.0024e-04
# Epoch 40/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 111ms/step - custom_mae: 0.1680 - loss: 8.2614e-07 - val_custom_mae: 0.2934 - val_loss: 2.2478e-04
# Epoch 41/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 114ms/step - custom_mae: 0.1693 - loss: 7.8190e-07 - val_custom_mae: 0.2936 - val_loss: 2.3143e-04
# Epoch 42/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - custom_mae: 0.1665 - loss: 6.9603e-07 - val_custom_mae: 0.2933 - val_loss: 2.2809e-04
# Epoch 43/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - custom_mae: 0.1663 - loss: 6.4547e-07 - val_custom_mae: 0.2949 - val_loss: 2.4258e-04
# Epoch 44/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - custom_mae: 0.1654 - loss: 5.4965e-07 - val_custom_mae: 0.2922 - val_loss: 2.0735e-04
# Epoch 45/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 115ms/step - custom_mae: 0.1657 - loss: 6.0260e-07 - val_custom_mae: 0.2946 - val_loss: 2.1246e-04
# Epoch 46/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 113ms/step - custom_mae: 0.1643 - loss: 5.4903e-07 - val_custom_mae: 0.2937 - val_loss: 2.1667e-04
# Epoch 47/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 19s 116ms/step - custom_mae: 0.1632 - loss: 5.3872e-07 - val_custom_mae: 0.2980 - val_loss: 2.5805e-04
# Epoch 48/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 113ms/step - custom_mae: 0.1626 - loss: 4.6530e-07 - val_custom_mae: 0.2974 - val_loss: 2.4566e-04
# Epoch 49/1000
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 114ms/step - custom_mae: 0.1634 - loss: 4.7673e-07 - val_custom_mae: 0.2973 - val_loss: 2.5017e-04
# I0000 00:00:1759504698.820367 4116207 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1759504698.820563 4116207 single_machine.cc:374] Starting new session
# I0000 00:00:1759504698.821544 4116207 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8092 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:03:00.0, compute capability: 8.6
# I0000 00:00:1759504699.164062 4116207 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8092 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:03:00.0, compute capability: 8.6
# I0000 00:00:1759504699.207925 4116207 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1759504699.208126 4116207 single_machine.cc:374] Starting new session
# I0000 00:00:1759504699.209500 4116207 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8092 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:03:00.0, compute capability: 8.6
# I0000 00:00:1759504699.757804 4116207 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8092 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:03:00.0, compute capability: 8.6
# I0000 00:00:1759504699.763659 4116207 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8092 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:03:00.0, compute capability: 8.6
# I0000 00:00:1759504699.768960 4116207 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8092 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:03:00.0, compute capability: 8.6
# I0000 00:00:1759504699.774209 4116207 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8092 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:03:00.0, compute capability: 8.6
# ✓ Completed Calgary → Results/Ablation/Calgary/PIELNET
